# %% [markdown]
# <a href="https://colab.research.google.com/github/Ricardo-IA/Procesamento_imagem/blob/main/Processamento_de_imagem_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Processamento de imagem no python

# %%
# !pip install pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import PIL

# %%
from PIL import Image

# %%
image = Image.open("/content/Imagem/coringa.jpg")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=972x501 at 0x7F209B7693D0>

# %%
from matplotlib import image
from matplotlib import pyplot

# %%
data = image.imread("/content/Imagem/coringa.jpg")

# %%
pyplot.imshow(data)

# %%
image2 = Image.fromarray(data)

# %%
type(image2)
# Out:
# PIL.Image.Image

# %%
from numpy import asarray

# %%
image = Image.open("/content/Imagem/coringa.jpg")

# %%
data = asarray(image)

# %%
image_cinza = image.convert(mode ="L")

# %%
image_cinza
# Out:
# <PIL.Image.Image image mode=L size=972x501 at 0x7F209B6F2AD0>

# %%
image_cinza = image.convert(mode ="1")

# %%
image_cinza
# Out:
# <PIL.Image.Image image mode=1 size=972x501 at 0x7F209AE41650>
